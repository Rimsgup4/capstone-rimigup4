# %% [markdown]
# # Testing the model

# %%
# %run "Training.ipynb"
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_15 (Dense)             (None, 25)                200
# _________________________________________________________________
# dense_16 (Dense)             (None, 25)                650
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 26
# ...
# Total params: 876
# Trainable params: 876
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0064 - val_loss: 0.0013
# Epoch 2/20
# 13/13 [==============================] - 0s 3ms/step - loss: 0.0052 - val_loss: 0.0010
# Epoch 3/20
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0047 - val_loss: 7.6599e-04
# Epoch 4/20
# ...

# %% [markdown]
# # Taking user inputs

# %%
X_Testing = np.array([[91,129.5,692.6,7,21.7,38,2.2]]) 

# %run "annn.ipynb"
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_33 (Dense)             (None, 25)                200
# _________________________________________________________________
# dense_34 (Dense)             (None, 25)                650
# _________________________________________________________________
# dense_35 (Dense)             (None, 1)                 26
# ...
# Total params: 876
# Trainable params: 876
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0011 - val_loss: 0.0069
# Epoch 2/20
# 13/13 [==============================] - 0s 3ms/step - loss: 8.5854e-04 - val_loss: 0.0065
# Epoch 3/20
# 13/13 [==============================] - 0s 3ms/step - loss: 7.5970e-04 - val_loss: 0.0063
# Epoch 4/20
# ...

# %% [markdown]
# # Prediction done by model

# %%
y_predict = model.predict(X_Testing)
y_predict.shape
# Out:
# WARNING:tensorflow:7 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002EE2E144D30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (1, 1)

# %% [markdown]
# # output

# %%
print('area=', y_predict[:,0])
if y_predict>50:
    print("fire is caught")
else:
    print("no fire is caught")
# Out:
# area= [26.521791]
# no fire is caught
